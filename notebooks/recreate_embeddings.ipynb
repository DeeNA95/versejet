# %% [markdown]
# # Recreate Verse Embeddings JSON
#
# This notebook regenerates the embeddings JSON file (`VersejetKJV.json`) from the original verse text file (`verses-1769.json`) using OpenAI's `text-embedding-3-small` embedding model.
#
# The output JSON will have the same structure as `VersejetKJV.json` including fields:
# - `_id` (generated UUID)
# - `book`
# - `chapter`
# - `verse`
# - `cleaned_text`
# - `embedding` (list of floats)
#
# Replace the existing embedding JSON with this to prevent embedding model mismatches in VerseJet.

# %%
# Import required libraries
import json
import os
import re
import time
import uuid
from typing import List, Dict
# %pip install --quiet python-dotenv
from dotenv import load_dotenv

load_dotenv()

import openai

# You will need to pip install openai if you haven't already
# !pip install openai

# Set your OpenAI API key
openai.api_key = os.getenv('OPENAI_API_KEY')  # or set your key here directly
if not openai.api_key:
    raise ValueError('OPENAI_API_KEY environment variable is not set')
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
os.getenv('OPENAI_API_KEY')
# Out:
# 'sk-your-actual-openai-api-key-here'

# %%
# Constants
VERSES_TEXT_PATH = '../verses-1769.json'  # adjust if you put the notebook elsewhere
OUTPUT_EMBEDDING_JSON_PATH = '../VersejetKJV_recreated.json'
EMBEDDING_MODEL = 'text-embedding-3-small'

# Regular expression to parse Bible reference
REF_REGEX = re.compile(r'^(.+?)\s+(\d+):(\d+)$')

MAX_BATCH_SIZE = 100  # number of embeddings per API call (modify if rate limits)

def parse_reference(ref: str):
    """Parse a verse reference into book, chapter, and verse."""
    m = REF_REGEX.match(ref)
    if not m:
        raise ValueError(f'Invalid verse reference format: {ref}')
    book, chapter, verse = m.group(1), int(m.group(2)), int(m.group(3))
    return book, chapter, verse

# %%
def chunk_list(lst: List, size: int) -> List[List]:
    """Split a list into chunks of specified size."""
    for i in range(0, len(lst), size):
        yield lst[i:i + size]

# %%
def generate_embeddings(texts: List[str], model: str) -> List[List[float]]:
    """Generate embeddings for a list of texts using OpenAI API (v1.x)."""
    response = openai.embeddings.create(
        input=texts,
        model=model
    )
    # The new API returns an object with a 'data' attribute, which is a list of objects with 'embedding'
    embeddings = [item.embedding for item in response.data]
    return embeddings

# %%
# Load original verse texts
with open(VERSES_TEXT_PATH, 'r', encoding='utf-8') as f:
    verse_texts: Dict[str, str] = json.load(f)

print(f"Loaded {len(verse_texts)} verses from {VERSES_TEXT_PATH}")
# Out:
# Loaded 31102 verses from ../verses-1769.json

# %%
# Prepare list for embedding generation
refs = sorted(verse_texts.keys())
texts_for_embedding = [verse_texts[ref].strip() for ref in refs]

# Verify example
print(f"Example verse reference: {refs[0]}")
print(f"Example verse text: {texts_for_embedding[0][:80]}...")
# Out:
# Example verse reference: 1 Chronicles 10:1
# Example verse text: Now the Philistines fought against Israel; and the men of Israel fled from befor...

# %%
# Generate embeddings in batches to avoid rate limits
all_embeddings = []
total = len(texts_for_embedding)
print(f"Generating embeddings for {total} verses in batches of {MAX_BATCH_SIZE}...")
for i, batch_texts in enumerate(chunk_list(texts_for_embedding, MAX_BATCH_SIZE)):
    print(f"Processing batch {i+1}/{(total + MAX_BATCH_SIZE - 1)//MAX_BATCH_SIZE}")
    try:
        batch_embeddings = generate_embeddings(batch_texts, EMBEDDING_MODEL)
    except Exception as e:
        print(f"Error generating embeddings at batch {i+1}: {e}")
        break
    all_embeddings.extend(batch_embeddings)
    time.sleep(.1)  # slight delay to avoid rate limits

assert len(all_embeddings) == total, f"Mismatch: expected {total}, got {len(all_embeddings)} embeddings"
# Out:
# Generating embeddings for 31102 verses in batches of 100...
# Processing batch 1/312
# Processing batch 2/312
# Processing batch 2/312
# Processing batch 3/312
# Processing batch 3/312
# Processing batch 4/312
# Processing batch 4/312
# Processing batch 5/312
# Processing batch 5/312
# Processing batch 6/312
# Processing batch 6/312
# Processing batch 7/312
# Processing batch 7/312
# Processing batch 8/312
# Processing batch 8/312
# Processing batch 9/312
# Processing batch 9/312
# Processing batch 10/312
# Processing batch 10/312
# Processing batch 11/312
# Processing batch 11/312
# Processing batch 12/312
# Processing batch 12/312
# Processing batch 13/312
# Processing batch 13/312
# Processing batch 14/312
# Processing batch 14/312
# Processing batch 15/312
# Processing batch 15/312
# Processing batch 16/312
# Processing batch 16/312
# Processing batch 17/312
# Processing batch 17/312
# Processing batch 18/312
# Processing batch 18/312
# Processing batch 19/312
# Processing batch 19/312
# Processing batch 20/312
# Processing batch 20/312
# Processing batch 21/312
# Processing batch 21/312
# Processing batch 22/312
# Processing batch 22/312
# Processing batch 23/312
# Processing batch 23/312
# Processing batch 24/312
# Processing batch 24/312
# Processing batch 25/312
# Processing batch 25/312
# Processing batch 26/312
# Processing batch 26/312
# Processing batch 27/312
# Processing batch 27/312
# Processing batch 28/312
# Processing batch 28/312
# Processing batch 29/312
# Processing batch 29/312
# Processing batch 30/312
# Processing batch 30/312
# Processing batch 31/312
# Processing batch 31/312
# Processing batch 32/312
# Processing batch 32/312
# Processing batch 33/312
# Processing batch 33/312
# Processing batch 34/312
# Processing batch 34/312
# Processing batch 35/312
# Processing batch 35/312
# Processing batch 36/312
# Processing batch 36/312
# Processing batch 37/312
# Processing batch 37/312
# Processing batch 38/312
# Processing batch 38/312
# Processing batch 39/312
# Processing batch 39/312
# Processing batch 40/312
# Processing batch 40/312
# Processing batch 41/312
# Processing batch 41/312
# Processing batch 42/312
# Processing batch 42/312
# Processing batch 43/312
# Processing batch 43/312
# Processing batch 44/312
# Processing batch 44/312
# Processing batch 45/312
# Processing batch 45/312
# Processing batch 46/312
# Processing batch 46/312
# Processing batch 47/312
# Processing batch 47/312
# Processing batch 48/312
# Processing batch 48/312
# Processing batch 49/312
# Processing batch 49/312
# Processing batch 50/312
# Processing batch 50/312
# Processing batch 51/312
# Processing batch 51/312
# Processing batch 52/312
# Processing batch 52/312
# Processing batch 53/312
# Processing batch 53/312
# Processing batch 54/312
# Processing batch 54/312
# Processing batch 55/312
# Processing batch 55/312
# Processing batch 56/312
# Processing batch 56/312
# Processing batch 57/312
# Processing batch 57/312
# Processing batch 58/312
# Processing batch 58/312
# Processing batch 59/312
# Processing batch 59/312
# Processing batch 60/312
# Processing batch 60/312
# Processing batch 61/312
# Processing batch 61/312
# Processing batch 62/312
# Processing batch 62/312
# Processing batch 63/312
# Processing batch 63/312
# Processing batch 64/312
# Processing batch 64/312
# Processing batch 65/312
# Processing batch 65/312
# Processing batch 66/312
# Processing batch 66/312
# Processing batch 67/312
# Processing batch 67/312
# Processing batch 68/312
# Processing batch 68/312
# Processing batch 69/312
# Processing batch 69/312
# Processing batch 70/312
# Processing batch 70/312
# Processing batch 71/312
# Processing batch 71/312
# Processing batch 72/312
# Processing batch 72/312
# Processing batch 73/312
# Processing batch 73/312
# Processing batch 74/312
# Processing batch 74/312
# Processing batch 75/312
# Processing batch 75/312
# Processing batch 76/312
# Processing batch 76/312
# Processing batch 77/312
# Processing batch 77/312
# Processing batch 78/312
# Processing batch 78/312
# Processing batch 79/312
# Processing batch 79/312
# Processing batch 80/312
# Processing batch 80/312
# Processing batch 81/312
# Processing batch 81/312
# Processing batch 82/312
# Processing batch 82/312
# Processing batch 83/312
# Processing batch 83/312
# Processing batch 84/312
# Processing batch 84/312
# Processing batch 85/312
# Processing batch 85/312
# Processing batch 86/312
# Processing batch 86/312
# Processing batch 87/312
# Processing batch 87/312
# Processing batch 88/312
# Processing batch 88/312
# Processing batch 89/312
# Processing batch 89/312
# Processing batch 90/312
# Processing batch 90/312
# Processing batch 91/312
# Processing batch 91/312
# Processing batch 92/312
# Processing batch 92/312
# Processing batch 93/312
# Processing batch 93/312
# Processing batch 94/312
# Processing batch 94/312
# Processing batch 95/312
# Processing batch 95/312
# Processing batch 96/312
# Processing batch 96/312
# Processing batch 97/312
# Processing batch 97/312
# Processing batch 98/312
# Processing batch 98/312
# Processing batch 99/312
# Processing batch 99/312
# Processing batch 100/312
# Processing batch 100/312
# Processing batch 101/312
# Processing batch 101/312
# Processing batch 102/312
# Processing batch 102/312
# Processing batch 103/312
# Processing batch 103/312
# Processing batch 104/312
# Processing batch 104/312
# Processing batch 105/312
# Processing batch 105/312
# Processing batch 106/312
# Processing batch 106/312
# Processing batch 107/312
# Processing batch 107/312
# Processing batch 108/312
# Processing batch 108/312
# Processing batch 109/312
# Processing batch 109/312
# Processing batch 110/312
# Processing batch 110/312
# Processing batch 111/312
# Processing batch 111/312
# Processing batch 112/312
# Processing batch 112/312
# Processing batch 113/312
# Processing batch 113/312
# Processing batch 114/312
# Processing batch 114/312
# Processing batch 115/312
# Processing batch 115/312
# Processing batch 116/312
# Processing batch 116/312
# Processing batch 117/312
# Processing batch 117/312
# Processing batch 118/312
# Processing batch 118/312
# Processing batch 119/312
# Processing batch 119/312
# Processing batch 120/312
# Processing batch 120/312
# Processing batch 121/312
# Processing batch 121/312
# Processing batch 122/312
# Processing batch 122/312
# Processing batch 123/312
# Processing batch 123/312
# Processing batch 124/312
# Processing batch 124/312
# Processing batch 125/312
# Processing batch 125/312
# Processing batch 126/312
# Processing batch 126/312
# Processing batch 127/312
# Processing batch 127/312
# Processing batch 128/312
# Processing batch 128/312
# Processing batch 129/312
# Processing batch 129/312
# Processing batch 130/312
# Processing batch 130/312
# Processing batch 131/312
# Processing batch 131/312
# Processing batch 132/312
# Processing batch 132/312
# Processing batch 133/312
# Processing batch 133/312
# Processing batch 134/312
# Processing batch 134/312
# Processing batch 135/312
# Processing batch 135/312
# Processing batch 136/312
# Processing batch 136/312
# Processing batch 137/312
# Processing batch 137/312
# Processing batch 138/312
# Processing batch 138/312
# Processing batch 139/312
# Processing batch 139/312
# Processing batch 140/312
# Processing batch 140/312
# Processing batch 141/312
# Processing batch 141/312
# Processing batch 142/312
# Processing batch 142/312
# Processing batch 143/312
# Processing batch 143/312
# Processing batch 144/312
# Processing batch 144/312
# Processing batch 145/312
# Processing batch 145/312
# Processing batch 146/312
# Processing batch 146/312
# Processing batch 147/312
# Processing batch 147/312
# Processing batch 148/312
# Processing batch 148/312
# Processing batch 149/312
# Processing batch 149/312
# Processing batch 150/312
# Processing batch 150/312
# Processing batch 151/312
# Processing batch 151/312
# Processing batch 152/312
# Processing batch 152/312
# Processing batch 153/312
# Processing batch 153/312
# Processing batch 154/312
# Processing batch 154/312
# Processing batch 155/312
# Processing batch 155/312
# Processing batch 156/312
# Processing batch 156/312
# Processing batch 157/312
# Processing batch 157/312
# Processing batch 158/312
# Processing batch 158/312
# Processing batch 159/312
# Processing batch 159/312
# Processing batch 160/312
# Processing batch 160/312
# Processing batch 161/312
# Processing batch 161/312
# Processing batch 162/312
# Processing batch 162/312
# Processing batch 163/312
# Processing batch 163/312
# Processing batch 164/312
# Processing batch 164/312
# Processing batch 165/312
# Processing batch 165/312
# Processing batch 166/312
# Processing batch 166/312
# Processing batch 167/312
# Processing batch 167/312
# Processing batch 168/312
# Processing batch 168/312
# Processing batch 169/312
# Processing batch 169/312
# Processing batch 170/312
# Processing batch 170/312
# Processing batch 171/312
# Processing batch 171/312
# Processing batch 172/312
# Processing batch 172/312
# Processing batch 173/312
# Processing batch 173/312
# Processing batch 174/312
# Processing batch 174/312
# Processing batch 175/312
# Processing batch 175/312
# Processing batch 176/312
# Processing batch 176/312
# Processing batch 177/312
# Processing batch 177/312
# Processing batch 178/312
# Processing batch 178/312
# Processing batch 179/312
# Processing batch 179/312
# Processing batch 180/312
# Processing batch 180/312
# Processing batch 181/312
# Processing batch 181/312
# Processing batch 182/312
# Processing batch 182/312
# Processing batch 183/312
# Processing batch 183/312
# Processing batch 184/312
# Processing batch 184/312
# Processing batch 185/312
# Processing batch 185/312
# Processing batch 186/312
# Processing batch 186/312
# Processing batch 187/312
# Processing batch 187/312
# Processing batch 188/312
# Processing batch 188/312
# Processing batch 189/312
# Processing batch 189/312
# Processing batch 190/312
# Processing batch 190/312
# Processing batch 191/312
# Processing batch 191/312
# Processing batch 192/312
# Processing batch 192/312
# Processing batch 193/312
# Processing batch 193/312
# Processing batch 194/312
# Processing batch 194/312
# Processing batch 195/312
# Processing batch 195/312
# Processing batch 196/312
# Processing batch 196/312
# Processing batch 197/312
# Processing batch 197/312
# Processing batch 198/312
# Processing batch 198/312
# Processing batch 199/312
# Processing batch 199/312
# Processing batch 200/312
# Processing batch 200/312
# Processing batch 201/312
# Processing batch 201/312
# Processing batch 202/312
# Processing batch 202/312
# Processing batch 203/312
# Processing batch 203/312
# Processing batch 204/312
# Processing batch 204/312
# Processing batch 205/312
# Processing batch 205/312
# Processing batch 206/312
# Processing batch 206/312
# Processing batch 207/312
# Processing batch 207/312
# Processing batch 208/312
# Processing batch 208/312
# Processing batch 209/312
# Processing batch 209/312
# Processing batch 210/312
# Processing batch 210/312
# Processing batch 211/312
# Processing batch 211/312
# Processing batch 212/312
# Processing batch 212/312
# Processing batch 213/312
# Processing batch 213/312
# Processing batch 214/312
# Processing batch 214/312
# Processing batch 215/312
# Processing batch 215/312
# Processing batch 216/312
# Processing batch 216/312
# Processing batch 217/312
# Processing batch 217/312
# Processing batch 218/312
# Processing batch 218/312
# Processing batch 219/312
# Processing batch 219/312
# Processing batch 220/312
# Processing batch 220/312
# Processing batch 221/312
# Processing batch 221/312
# Processing batch 222/312
# Processing batch 222/312
# Processing batch 223/312
# Processing batch 223/312
# Processing batch 224/312
# Processing batch 224/312
# Processing batch 225/312
# Processing batch 225/312
# Processing batch 226/312
# Processing batch 226/312
# Processing batch 227/312
# Processing batch 227/312
# Processing batch 228/312
# Processing batch 228/312
# Processing batch 229/312
# Processing batch 229/312
# Processing batch 230/312
# Processing batch 230/312
# Processing batch 231/312
# Processing batch 231/312
# Processing batch 232/312
# Processing batch 232/312
# Processing batch 233/312
# Processing batch 233/312
# Processing batch 234/312
# Processing batch 234/312
# Processing batch 235/312
# Processing batch 235/312
# Processing batch 236/312
# Processing batch 236/312
# Processing batch 237/312
# Processing batch 237/312
# Processing batch 238/312
# Processing batch 238/312
# Processing batch 239/312
# Processing batch 239/312
# Processing batch 240/312
# Processing batch 240/312
# Processing batch 241/312
# Processing batch 241/312
# Processing batch 242/312
# Processing batch 242/312
# Processing batch 243/312
# Processing batch 243/312
# Processing batch 244/312
# Processing batch 244/312
# Processing batch 245/312
# Processing batch 245/312
# Processing batch 246/312
# Processing batch 246/312
# Processing batch 247/312
# Processing batch 247/312
# Processing batch 248/312
# Processing batch 248/312
# Processing batch 249/312
# Processing batch 249/312
# Processing batch 250/312
# Processing batch 250/312
# Processing batch 251/312
# Processing batch 251/312
# Processing batch 252/312
# Processing batch 252/312
# Processing batch 253/312
# Processing batch 253/312
# Processing batch 254/312
# Processing batch 254/312
# Processing batch 255/312
# Processing batch 255/312
# Processing batch 256/312
# Processing batch 256/312
# Processing batch 257/312
# Processing batch 257/312
# Processing batch 258/312
# Processing batch 258/312
# Processing batch 259/312
# Processing batch 259/312
# Processing batch 260/312
# Processing batch 260/312
# Processing batch 261/312
# Processing batch 261/312
# Processing batch 262/312
# Processing batch 262/312
# Processing batch 263/312
# Processing batch 263/312
# Processing batch 264/312
# Processing batch 264/312
# Processing batch 265/312
# Processing batch 265/312
# Processing batch 266/312
# Processing batch 266/312
# Processing batch 267/312
# Processing batch 267/312
# Processing batch 268/312
# Processing batch 268/312
# Processing batch 269/312
# Processing batch 269/312
# Processing batch 270/312
# Processing batch 270/312
# Processing batch 271/312
# Processing batch 271/312
# Processing batch 272/312
# Processing batch 272/312
# Processing batch 273/312
# Processing batch 273/312
# Processing batch 274/312
# Processing batch 274/312
# Processing batch 275/312
# Processing batch 275/312
# Processing batch 276/312
# Processing batch 276/312
# Processing batch 277/312
# Processing batch 277/312
# Processing batch 278/312
# Processing batch 278/312
# Processing batch 279/312
# Processing batch 279/312
# Processing batch 280/312
# Processing batch 280/312
# Processing batch 281/312
# Processing batch 281/312
# Processing batch 282/312
# Processing batch 282/312
# Processing batch 283/312
# Processing batch 283/312
# Processing batch 284/312
# Processing batch 284/312
# Processing batch 285/312
# Processing batch 285/312
# Processing batch 286/312
# Processing batch 286/312
# Processing batch 287/312
# Processing batch 287/312
# Processing batch 288/312
# Processing batch 288/312
# Processing batch 289/312
# Processing batch 289/312
# Processing batch 290/312
# Processing batch 290/312
# Processing batch 291/312
# Processing batch 291/312
# Processing batch 292/312
# Processing batch 292/312
# Processing batch 293/312
# Processing batch 293/312
# Processing batch 294/312
# Processing batch 294/312
# Processing batch 295/312
# Processing batch 295/312
# Processing batch 296/312
# Processing batch 296/312
# Processing batch 297/312
# Processing batch 297/312
# Processing batch 298/312
# Processing batch 298/312
# Processing batch 299/312
# Processing batch 299/312
# Processing batch 300/312
# Processing batch 300/312
# Processing batch 301/312
# Processing batch 301/312
# Processing batch 302/312
# Processing batch 302/312
# Processing batch 303/312
# Processing batch 303/312
# Processing batch 304/312
# Processing batch 304/312
# Processing batch 305/312
# Processing batch 305/312
# Processing batch 306/312
# Processing batch 306/312
# Processing batch 307/312
# Processing batch 307/312
# Processing batch 308/312
# Processing batch 308/312
# Processing batch 309/312
# Processing batch 309/312
# Processing batch 310/312
# Processing batch 310/312
# Processing batch 311/312
# Processing batch 311/312
# Processing batch 312/312
# Processing batch 312/312

# %%
# Construct output data structure matching VersejetKJV.json
output_verses = []

for idx, ref in enumerate(refs):
    book, chapter, verse = parse_reference(ref)
    cleaned_text = verse_texts[ref].strip()
    embedding = all_embeddings[idx]

    verse_entry = {
        "_id": {"$oid": str(uuid.uuid4())},
        "book": book,
        "chapter": chapter,
        "verse": verse,
        "cleaned_text": cleaned_text,
        "embedding": embedding
    }
    output_verses.append(verse_entry)

print(f"Constructed {len(output_verses)} verse records with embeddings")
# Out:
# Constructed 31102 verse records with embeddings

# %%
# Save to JSON file
with open(OUTPUT_EMBEDDING_JSON_PATH, 'w', encoding='utf-8') as f_out:
    json.dump(output_verses, f_out, indent=2)

print(f"Saved new embedding JSON to {OUTPUT_EMBEDDING_JSON_PATH}")
# Out:
# Saved new embedding JSON to ../VersejetKJV_recreated.json
